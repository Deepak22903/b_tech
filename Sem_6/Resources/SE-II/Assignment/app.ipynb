# %% [markdown]
# ### TO DO
# #### - [ ] 1 deep learning
# #### - [ ] 3 ML models

# %%
! pip install scikit-learn
! pip install pandas
! pip install numpy
! pip install matplotlib
! pip install seaborn
! pip install keras
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/162.6 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.6 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 162.6/162.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.6 MB 27.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/7.6 MB 21.1 MB/s eta 0:00:01
#    --------- ------------------------------ 1.7/7.6 MB 15.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.6 MB 12.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.6 MB 13.0 MB/s eta 0:00:01
#    ------------ --------------------------- 2.3/7.6 MB 9.2 MB/s eta 0:00:01
#    --------------- ------------------------ 2.9/7.6 MB 10.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# Load the data
data = pd.read_csv('TCS1.csv')

# Print the first 5 rows of the dataframe.
print(data.head())

# Get the column names
data.columns
# Out:
#   symbol                       date  close   high     low   open    volume  \
# 0    TCS  2013-11-01 00:00:00+00:00  36.20  37.00  32.100  35.00  14667600
# 1    TCS  2013-11-04 00:00:00+00:00  35.35  36.80  34.690  36.80   1586600
# 2    TCS  2013-11-05 00:00:00+00:00  35.35  35.50  34.821  35.11    337700
# 3    TCS  2013-11-06 00:00:00+00:00  35.90  36.49  35.610  35.61    549600
# 4    TCS  2013-11-07 00:00:00+00:00  35.31  36.80  34.120  36.80    883700
#
#     adjClose    adjHigh     adjLow    adjOpen  adjVolume  divCash  splitFactor
# 0  34.058592  34.811268  30.201127  32.929577   14667600      0.0          1.0
# 1  33.258873  34.623099  32.637915  34.623099    1586600      0.0          1.0
# 2  33.258873  33.400000  32.761166  33.033070     337700      0.0          1.0
# 3  33.776338  34.331437  33.503493  33.503493     549600      0.0          1.0
# 4  33.221239  34.623099  32.101634  34.623099     883700      0.0          1.0
# ...

# %%
# Split the data in to 70% training and 30% test data

from sklearn.model_selection import train_test_split

# Split the data into training and test sets the target column is called 'closed'
train_features, test_features, train_labels, test_labels = train_test_split(data.drop('target', axis=1),
                                                                            data['target'],
                                                                            test_size = 0.3,
                                                                            random_state=42)

# Print the shapes of the training and testing data
print(train_features.shape)

print(test_features.shape)

# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# Train the model on training data
rf.fit(train_features, train_labels)

# Use the forest's predict method on the test data

predictions = rf.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')

# Get numerical feature importances
importances = list(rf.feature_importances_)

# Plot the feature importances of the forest
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# list of x locations for plotting
x_values = list(range(len(importances)))

# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')

# Tick labels for x axis
plt.xticks(x_values, data.columns, rotation='vertical')

# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances')

# Show the plot
plt.show()
